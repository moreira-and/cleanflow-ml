# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.infrastructure.repositories.i_query.raw import YfinanceLoader

yfince_loader = YfinanceLoader(start_date="2025-01-01", end_date="2025-02-01")

yfince_data = yfince_loader.get_by_id(["^BVSP"])
# Out:
# 2025-08-16 16:33:01.010 | INFO     | src.infrastructure.repositories.i_query.raw.yfinance_loader:get_by_id:65 - Downloading IndBovespa (^BVSP) from yfinance...

# %%
yfince_data["IndBovespa"].tail(10)
# Out:
#             IndBovespa_Close  IndBovespa_High  IndBovespa_Low  \
# Date
# 2025-01-20          122543.0         123098.0        121511.0
# 2025-01-21          123338.0         123462.0        122290.0
# 2025-01-22          122972.0         123865.0        122926.0
# 2025-01-23          122483.0         123958.0        122159.0
# 2025-01-24          122447.0         122908.0        122196.0
# 2025-01-27          124862.0         124862.0        122207.0
# 2025-01-28          124056.0         124881.0        123973.0
# 2025-01-29          123432.0         124767.0        123278.0
# 2025-01-30          126913.0         127169.0        123432.0
# 2025-01-31          126135.0         127532.0        126057.0
#
#             IndBovespa_Open  IndBovespa_Volume
# Date
# 2025-01-20         122349.0            4185300
# 2025-01-21         122850.0            7819600
# 2025-01-22         123345.0            9975100
# 2025-01-23         122965.0            9491400
# ...
